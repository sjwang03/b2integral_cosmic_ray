# %% [markdown]
# # Prerequisites for ```binder``` execution
#
# If you are runnning on ```binder``` you will be needing to install following python packages to excute data processing:
#
# ```gdown```
#
# Therefore, be sure to execute the following cell every time you start a new ```binder``` session.

# %%
import sys
import subprocess

# Run pip install quietly
subprocess.run(
    [sys.executable, "-m", "pip", "install", "gdown"],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.DEVNULL,
    check=True
)

print("Prerequisites installed successfully. Go on for data process.")

# %% [markdown]
# # Download data using ```gdown```

# %%
import gdown

# %%
gdown.download("https://drive.google.com/file/d/13xeXw7mYt6DiEjV2QDTVCmkoibz4ze7w/view?usp=sharing", "../data/test/sampledata.h5")
# Out:
# /application/anaconda3/envs/sjwang/lib/python3.8/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=13xeXw7mYt6DiEjV2QDTVCmkoibz4ze7w
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/13xeXw7mYt6DiEjV2QDTVCmkoibz4ze7w/view?usp=sharing
# To: /disk/work_wangshijie/b2integral/cosmic_ray/data/test/sampledata.h5
# 110kB [00:00, 16.5MB/s]
# './cosmic_ray/data/test/sampledata.h5'
